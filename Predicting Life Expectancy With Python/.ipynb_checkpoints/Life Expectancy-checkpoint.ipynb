# %% [markdown]
# # Life Expectancy With Python
#
# ### Importing required libraries:
#
# 1.pandas: High level data manipulation tool.Its key data structure is DataFrame.(based on numpy)
# 2.numpy:Multidimensional array of objects
# 3.seaborn:Data visualisation library (based on matplotlib)
# 4.matplotlib:Plotting library for python.
# 5.types:Dynamic type creation and names for built-in types.
# 6.sklearn:Tools for ML and statistical modelling including classification,regression,clustering.

# %%
import types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.



# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

# If you are reading an Excel file into a pandas DataFrame, replace `read_csv` by `read_excel` in the next statement.

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import types
from botocore.client import Config
import ibm_boto3
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import make_scorer
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV

# %%
def __iter__(self): return 0

# @hidden_cell

# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.

# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

# If you are reading an Excel file into a pandas DataFrame, replace `read_csv` by `read_excel` in the next statement.
life_data = pd.read_csv(body)
life_data.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
life_data=pd.read_csv('data.csv')

# %%
life_data.dtypes
# Out:
# Country                             object
# Year                                 int64
# Status                              object
# Life expectancy                    float64
# Adult Mortality                    float64
# infant deaths                        int64
# Alcohol                            float64
# percentage expenditure             float64
# Hepatitis B                        float64
# Measles                              int64
#  BMI                               float64
# under-five deaths                    int64
# Polio                              float64
# Total expenditure                  float64
# Diphtheria                         float64
#  HIV/AIDS                          float64
# GDP                                float64
# Population                         float64
#  thinness  1-19 years              float64
#  thinness 5-9 years                float64
# Income composition of resources    float64
# Schooling                          float64
# ...

# %% [markdown]
# ### Data Preprocessing
# 1. We drop the column Year and group the rows by Country by taking a mean of all values in different years.
# 2. We convert the Country,Status column into codes( ordered categorical type) by using astype .
#
# ### Missing Data
# 1. isnull is used to find missing data and mean value(columnwise) is considered as means to fill the missing values using fillna method.

# %%
life_data = life_data.drop('Year', axis = 1)

# %%
life_data['Country'] = life_data['Country'].astype('category')
life_data['Country'] = life_data['Country'].cat.codes
life_data.head()
# Out:
#    Country      Status  Life expectancy   Adult Mortality  infant deaths  \
# 0        0  Developing              65.0            263.0             62
# 1        0  Developing              59.9            271.0             64
# 2        0  Developing              59.9            268.0             66
# 3        0  Developing              59.5            272.0             69
# 4        0  Developing              59.2            275.0             71
#
#    Alcohol  percentage expenditure  Hepatitis B  Measles    BMI   ...  Polio  \
# 0     0.01               71.279624         65.0      1154   19.1  ...    6.0
# 1     0.01               73.523582         62.0       492   18.6  ...   58.0
# 2     0.01               73.219243         64.0       430   18.1  ...   62.0
# 3     0.01               78.184215         67.0      2787   17.6  ...   67.0
# 4     0.01                7.097109         68.0      3013   17.2  ...   68.0
#
# ...

# %%
life_data['Status'] = life_data['Status'].astype('category')
life_data['Status'] = life_data['Status'].cat.codes

# %%
life_data = life_data.groupby('Country').mean()

# %%
life_data.columns
life_data.dtypes
# Out:
# Status                                int8
# Life expectancy                    float64
# Adult Mortality                    float64
# infant deaths                      float64
# Alcohol                            float64
# percentage expenditure             float64
# Hepatitis B                        float64
# Measles                            float64
#  BMI                               float64
# under-five deaths                  float64
# Polio                              float64
# Total expenditure                  float64
# Diphtheria                         float64
#  HIV/AIDS                          float64
# GDP                                float64
# Population                         float64
#  thinness  1-19 years              float64
#  thinness 5-9 years                float64
# Income composition of resources    float64
# Schooling                          float64
# dtype: object

# %%
life_labels = life_data['Life expectancy ']
life_features = life_data.drop('Life expectancy ', axis = 1)

# %%
life_features.isnull().sum()
# Out:
# Status                              0
# Adult Mortality                    10
# infant deaths                       0
# Alcohol                             2
# percentage expenditure              0
# Hepatitis B                         9
# Measles                             0
#  BMI                                4
# under-five deaths                   0
# Polio                               0
# Total expenditure                   2
# Diphtheria                          0
#  HIV/AIDS                           0
# GDP                                30
# Population                         48
#  thinness  1-19 years               4
#  thinness 5-9 years                 4
# Income composition of resources    17
# Schooling                          13
# dtype: int64

# %%
life_features.fillna(value = life_features.mean(), inplace = True)

# %%
life_labels.fillna(value = life_labels.mean(), inplace = True)

# %%
life_features.head()
# Out:
#          Status  Adult Mortality  infant deaths   Alcohol  \
# Country
# 0             1         269.0625        78.2500  0.014375
# 1             1          45.0625         0.6875  4.848750
# 2             1         108.1875        20.3125  0.406667
# 3             1         328.5625        83.7500  5.740667
# 4             1         127.5000         0.0000  7.949333
#
#          percentage expenditure  Hepatitis B   Measles       BMI   \
# Country
# 0                     34.960110    64.562500  2362.2500  15.51875
# 1                    193.259091    98.000000    53.3750  49.06875
# 2                    236.185241    78.000000  1943.8750  48.74375
# 3                    102.100268    70.222222  3561.3125  18.01875
# 4                   1001.585226    98.266667     0.0000  38.42500
#
#          under-five deaths     Polio  Total expenditure  Diphtheria   \
# Country
# 0                  107.5625  48.3750           8.252500      52.3125
# ...

# %% [markdown]
# ## EDA
#
# 1. We notice Positive Correlation of GDP,Percentage Expenditure with Life Expectancy.
# 2. We notice no correlation of alcohol on life expectancy.
# 3. We notice negative correlation of HIV/AIDS ,adult mortality with Life Expectancy.

# %%
import matplotlib.pyplot as plt
plt.scatter(life_data.GDP, life_data['Life expectancy '])
plt.xlabel('GDP')
plt.ylabel('Life expectancy')
# Out:
# Text(0, 0.5, 'Life expectancy')

# %%
plt.scatter(life_data[' HIV/AIDS'], life_data['Life expectancy '])
plt.xlabel('HIV/AIDS')
plt.ylabel('Life expectancy')
# Out:
# Text(0, 0.5, 'Life expectancy')

# %%
plt.scatter(life_data['percentage expenditure'], life_data['Life expectancy '])
plt.xlabel('Percentage Healhcare expenditure')
plt.ylabel('Life expectancy')
# Out:
# Text(0, 0.5, 'Life expectancy')

# %%
plt.scatter(life_data['Alcohol'], life_data['Life expectancy '])
plt.xlabel('Alcohol')
plt.ylabel('Life expectancy')
# Out:
# Text(0, 0.5, 'Life expectancy')

# %%
plt.scatter(life_data['Adult Mortality'], life_data['Life expectancy '])
plt.xlabel('Alcohol')
plt.ylabel('Life expectancy')
# Out:
# Text(0, 0.5, 'Life expectancy')

# %% [markdown]
# ### Understanding and Visualising the data

# %%
#import plotly
#from plotly.offline import download_plotlyjs ,init_notebook_mode,plot,iplot
#import pandas as pd
import seaborn as sns

# %%
import plotly.graph_objs as go

# %%
import chart_studio.plotly as py

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
data=pd.read_csv('data.csv')

# %%
df=data

# %%
df = df.drop('Year', axis = 1)

# %%
df.fillna(value = df.mean(), inplace = True)

# %%
df = df.groupby('Country').mean()

# %%
df
# Out:
#                                     Life expectancy   Adult Mortality  \
# Country
# Afghanistan                                 58.19375         269.0625
# Albania                                     75.15625          45.0625
# Algeria                                     73.61875         108.1875
# Angola                                      49.01875         328.5625
# Antigua and Barbuda                         75.05625         127.5000
# ...                                              ...              ...
# Venezuela (Bolivarian Republic of)          73.38750         163.0000
# Viet Nam                                    74.77500         126.5625
# Yemen                                       63.86250         211.8125
# Zambia                                      53.90625         354.3125
# Zimbabwe                                    50.48750         462.3750
#
#                                     infant deaths   Alcohol  \
# Country
# ...

# %%
df.columns
# Out:
# Index(['Life expectancy ', 'Adult Mortality', 'infant deaths', 'Alcohol',
#        'percentage expenditure', 'Hepatitis B', 'Measles ', ' BMI ',
#        'under-five deaths ', 'Polio', 'Total expenditure', 'Diphtheria ',
#        ' HIV/AIDS', 'GDP', 'Population', ' thinness  1-19 years',
#        ' thinness 5-9 years', 'Income composition of resources', 'Schooling'],
#       dtype='object')

# %% [markdown]
# # Distribution Plot
# How is GDP distributed across countries?
# How does life expectancy vary across countries?
# How are different parameters like schooling,expenditure on healthcare distributed?

# %%
sns.distplot(df['GDP'],bins=8)

# %%
sns.distplot(df['Schooling'],bins=30)#schooling varies from 0 to 20 years approx

# %%
sns.distplot(df['Total expenditure'],bins=30)

# %%
sns.distplot(df['Life expectancy '],bins=30) #varies as 40 to 85 years

# %% [markdown]
# # Pairplot
# This helps to understand the coorelation between different fields of our dataset.
#
# Analysis: We see linear relationship between GDP and percentage expenditure.(Zooming the below picture)

# %%
df_select=df[['GDP','Schooling','Life expectancy ','Adult Mortality', 'infant deaths', 'Alcohol',
       'percentage expenditure','Total expenditure','Population']]

# %%
sns.pairplot(df_select,height=5)

# %% [markdown]
# # Heatmap
# Heatmap helps us identify data correlation based on the values of colors
#
# Analysis:
# life expectancy and schooling ,percentage expenditure on health are highly correlated.
# GDP and percentage expenditure on health is highly correlated.

# %%
sns.heatmap(df_select.corr(),cmap='PuBuGn')

# %%
#Interactive Charts with Plotly
They help in visualisation by being interactive.
Analysis: Scatter plot of GDP vs Life Expectancy and Percentage Expenditure vs Life Expectancy.

# %%
chart_studio.tools.set_credentials_file(username='veditakamat',
                                        api_key='3mytmBTS525Nx0c4YhwX'
                                       
                                       )

# %%
import cufflinks as cf
import plotly
import plotly.tools
import chart_studio.plotly

# %%
# !pip install --upgrade nbformat
# Out:
# ...
#   Attempting uninstall: nbformat
#     Found existing installation: nbformat 5.0.4
#     Uninstalling nbformat-5.0.4:
#       Successfully uninstalled nbformat-5.0.4
# ...

# %%
trace_1=go.Scatter(
    x=df['GDP'],
    y=df['Life expectancy '],
    mode="markers",
    name= 'GDP vs Life Expectancy'
)
trace_2=go.Scatter(
    x=df['percentage expenditure'],
    y=df['Life expectancy '],
    mode="markers",
    name= 'Percentage Expenditure vs Life Expectancy'
)
data_vis=[trace_1 ,trace_2]

layout= dict(
        title="compare"
)
fig = dict(data=data_vis,layout=layout)
iplot(fig,filename="hello")
# Out:
# <div>
#
#
#             <div id="53d11460-e2f5-426e-b3c9-6945f51fa18b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("53d11460-e2f5-426e-b3c9-6945f51fa18b")) {
#                     Plotly.newPlot(
#                         '53d11460-e2f5-426e-b3c9-6945f51fa18b',
# ...

# %% [markdown]
# # Life Expectancy of India
# Since India is my mother nation ,I have tried to analyse it in depth
# Analysis: From 2000 to 2014 Life Expectancy of India has increased continuously from 62 to 68.
#           This may be due to several factors.

# %%
d=data[data['Country']== 'India']

# %%
df_select=d[['GDP']]
df_select.iplot(kind='box',filename='box-plot')
# Out:
# <div>
#
#
#             <div id="f9abc76c-d6d4-417c-9bd9-896bca6f357f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plotly.com';
#
#                 if (document.getElementById("f9abc76c-d6d4-417c-9bd9-896bca6f357f")) {
#                     Plotly.newPlot(
#                         'f9abc76c-d6d4-417c-9bd9-896bca6f357f',
#                         [{"boxpoints": false, "line": {"width": 1.3}, "marker": {"color": "rgba(255, 153, 51, 1.0)"}, "name": "GDP", "orientation": "v", "type": "box", "y": [1613.1887800000002, 1573.11889, 1452.195373, 1446.98541, 1461.671957, 1345.77153, 19.317764999999998, 991.484634, 118.166373, 792.2596980000001, 77.819, 621.3183767, 541.1352279, 466.2842, 447.13896600000004, 438.86463399999997]}],
# ...

# %%
df_plot=d[['GDP','Schooling','Life expectancy ', 'Alcohol',
       'percentage expenditure','Total expenditure','Population']]

# %%
sns.pairplot(df_plot,height=5)

# %%
sns.heatmap(df_plot.corr(),cmap='PuBuGn')#GDP has a correlation with almost every other field here
#Life expectancy and schooling shows correlation.

# %%
#GDP has been constantly increasing and percentage expenditure also shows somewhat increasing trend.
trace_1=go.Scatter(
    x=d['GDP'],
    y=d['Life expectancy '],
    mode="markers",
    name= 'GDP vs Life Expectancy'
)
trace_2=go.Scatter(
    x=d['percentage expenditure'],
    y=d['Life expectancy '],
    mode="markers",
    name= 'Percentage Expenditure vs Life Expectancy'
)
data_vis=[trace_1 ,trace_2]

layout= dict(
        title="compare"
)
fig = dict(data=data_vis,layout=layout)
iplot(fig,filename="hello")
# Out:
# <div>
#
#
#             <div id="dc95a517-ef18-481c-89b9-2001e60ec17b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("dc95a517-ef18-481c-89b9-2001e60ec17b")) {
#                     Plotly.newPlot(
#                         'dc95a517-ef18-481c-89b9-2001e60ec17b',
# ...

# %%
trace0=go.Bar(x=d['Year'],y=d['Life expectancy '])
data=[trace0]
layout= go.Layout(title="India's Life Expectancy since 2000")
fig=go.Figure(data=data,layout=layout)
chart_studio.plotly.iplot(fig,filename="India's Life Expectancy since 2000")
# Out:
#         <iframe
#             width="100%"
#             height="525px"
#             src="https://plotly.com/~veditakamat/1.embed"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # Life Expectancy in 2012 over the world-Visualisation
# visualising life expectancy in a single picture with colors provides a lot of information in a single picture.
# We find that life expectancy is very high in Developed Countries like Germany,France,China in 2012~ 74-83 years
# In India the life expectancy is 67.8 in 2012.
# Hence we realise that developed countries have greater life expectancies than developing.

# %%
data1=pd.read_csv('data.csv')

# %%
data2=data1[data1['Year']==2012]

# %%
data=dict(type='choropleth',
         colorscale='electric',
          reversescale=True,
          locations=data2['Country'],
          locationmode="country names",
          z=data2['Life expectancy '],
          text=data2['Country'],
          colorbar={'title':'Life Expectancy'},
         
         
         )

layout=dict(title_text='Life Expectancy in 2012')
fig=go.Figure(data=data,layout=layout)
chart_studio.plotly.iplot(fig,filename="chloropleth")
# Out:
#         <iframe
#             width="100%"
#             height="525px"
#             src="https://plotly.com/~veditakamat/11.embed"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # Train and Test Data
# Consideration: 80% data for training purpose
#                20% data for testing purpose
# Used Lasso Regression Model for training and testing purpose:
# r^2 score on training data: 93%
# Accuracy : 90%

# %%
life_features_train, life_features_test, life_labels_train, life_labels_test = train_test_split(life_features, life_labels, train_size = 0.8, test_size = 0.2)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.metrics import make_scorer

# %% [markdown]
# # Linear Regression
# The model is fitted first on the trained data the R square is 0.93 on the training data.Later its R square is checked on the testing data. The score is 89 % in the iteration of writing. We also calculate the MAE (the modulus between the predicted and the real value) at 2.33 and the MSE (the same only put to the power of 2) at 8.66.

# %%
#linear regression
linear_model = LinearRegression()
linear_model.fit(life_features_train, life_labels_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print('R_square score on the training: %.2f' % linear_model.score(life_features_train, life_labels_train))
# Out:
# R_square score on the training: 0.93

# %%
linear_model_predict = linear_model.predict(life_features_test)

# %%
print('Coefficients: \n', linear_model.coef_)
print("Mean squared error: %.2f"
      % mean_squared_error(life_labels_test, linear_model_predict))
print("Mean absolute error: %.2f"
      % mean_absolute_error(life_labels_test, linear_model_predict))
print('R_square score: %.2f' % r2_score(life_labels_test, linear_model_predict))
# Out:
# Coefficients:
#  [-8.69606162e-02 -5.12836584e-02  5.38709539e-02  1.65949766e-01
#   4.57092734e-04 -2.91074050e-02  1.93390829e-05  4.33144634e-02
#  -4.65105802e-02 -6.07358387e-03  7.41114062e-02  1.05268583e-01
#  -1.65660907e-01 -1.43581343e-05  1.54807939e-08 -2.23539575e-01
#   2.62915103e-01  5.44399985e+00  3.17440664e-01]
# Mean squared error: 8.66
# Mean absolute error: 2.33
# R_square score: 0.89

# %% [markdown]
# # Ridge, Lasso and Elastic Regression
#
# The Lasso Regression uses the L1 regularization which reduces some coefficent weights to zero.
# The best parameters for the Lasso Regression are alpha = 1, and max iterations set to 100. The R square is a little higher at 92 % on the training data and 90 % on the test data .
# The errors continue to be same as other regressions applied.

# %%
scoring = make_scorer(r2_score)

# %%
grid_cv = GridSearchCV(Ridge(),
              param_grid={'alpha': range(0, 10), 'max_iter' : [10, 100, 1000]},
              scoring=scoring, cv=5, refit=True)

# %%
grid_cv.fit(life_features_train, life_labels_train)
# Out:
# C:\Users\VEDITA KAMAT\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:148: LinAlgWarning:
#
# Ill-conditioned matrix (rcond=4.4346e-18): result may not be accurate.
#
# C:\Users\VEDITA KAMAT\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:148: LinAlgWarning:
#
# Ill-conditioned matrix (rcond=3.55663e-18): result may not be accurate.
#
# C:\Users\VEDITA KAMAT\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:148: LinAlgWarning:
#
# Ill-conditioned matrix (rcond=4.16982e-18): result may not be accurate.
#
# C:\Users\VEDITA KAMAT\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:148: LinAlgWarning:
#
# Ill-conditioned matrix (rcond=4.20645e-18): result may not be accurate.
#
# C:\Users\VEDITA KAMAT\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:148: LinAlgWarning:
#
# Ill-conditioned matrix (rcond=3.11958e-17): result may not be accurate.
#
# ...

# %%
print("Best Parameters: " + str(grid_cv.best_params_))
result = grid_cv.cv_results_
print("R^2 score on training data: %.2f" %grid_cv.score(life_features_train, life_labels_train))
print("R^2 score: %.2f"% r2_score(life_labels_test, grid_cv.best_estimator_.predict(life_features_test)))
# Out:
# Best Parameters: {'alpha': 9, 'max_iter': 10}
# R^2 score on training data: 0.93
# R^2 score: 0.88

# %%
print("Mean squared error: %.2f"
      % mean_squared_error(life_labels_test, linear_model_predict))
print("Mean absolute error: %.2f"
      % mean_absolute_error(life_labels_test, linear_model_predict))
# Out:
# Mean squared error: 8.66
# Mean absolute error: 2.33

# %%
scoring = make_scorer(r2_score)
grid_cv = GridSearchCV(Lasso(),
              param_grid={'alpha': range(0, 10), 'max_iter' : [10, 100, 1000]},
              scoring=scoring, cv=5, refit=True)

grid_cv.fit(life_features_train, life_labels_train)
print("Best Parameters: " + str(grid_cv.best_params_))

result = grid_cv.cv_results_
print("R^2 score on training data: %.2f" % grid_cv.score(life_features_train, life_labels_train))
print("R^2 score: %.2f"
      % r2_score(life_labels_test, grid_cv.best_estimator_.predict(life_features_test)))
print("Mean squared error: %.2f"
      % mean_squared_error(life_labels_test, linear_model_predict))
print("Mean absolute error: %.2f"
      % mean_absolute_error(life_labels_test, linear_model_predict))
# Out:
# C:\Users\VEDITA KAMAT\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:515: UserWarning:
#
# With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#
# C:\Users\VEDITA KAMAT\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: UserWarning:
#
# Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#
# C:\Users\VEDITA KAMAT\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 327.87367715211866, tolerance: 0.9742700094020282
#
# C:\Users\VEDITA KAMAT\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:515: UserWarning:
#
# With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#
# ...

# %%
scoring = make_scorer(r2_score)
grid_cv = GridSearchCV(ElasticNet(),
              param_grid={'alpha': range(0, 10), 'max_iter' : [10, 100, 1000], 'l1_ratio' : [0.1, 0.4, 0.8]},
              scoring=scoring, cv=5, refit=True)

grid_cv.fit(life_features_train, life_labels_train)
print("Best Parameters: " + str(grid_cv.best_params_))

result = grid_cv.cv_results_
print("R^2 score on training data: %.2f" % grid_cv.score(life_features_train, life_labels_train))
print("R^2 score: %.2f"
      % r2_score(life_labels_test, grid_cv.best_estimator_.predict(life_features_test)))
print("Mean squared error: %.2f"
      % mean_squared_error(life_labels_test, linear_model_predict))
print("Mean absolute error: %.2f"
      % mean_absolute_error(life_labels_test, linear_model_predict))
# Out:
# C:\Users\VEDITA KAMAT\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:515: UserWarning:
#
# With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#
# C:\Users\VEDITA KAMAT\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: UserWarning:
#
# Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#
# C:\Users\VEDITA KAMAT\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 327.87367715211866, tolerance: 0.9742700094020282
#
# C:\Users\VEDITA KAMAT\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:515: UserWarning:
#
# With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#
# ...

# %% [markdown]
# # Polynomial Features
# It is the worst model since R score value has come out to be negative.

# %%
quad_feature_transformer = PolynomialFeatures(2, interaction_only = True)
quad_feature_transformer.fit(life_features_train)
life_features_train_quad = quad_feature_transformer.transform(life_features_train)
life_features_test_quad = quad_feature_transformer.transform(life_features_test)
poly_model_quad = LinearRegression()
poly_model_quad.fit(life_features_train_quad, life_labels_train)
accuracy_score_quad = poly_model_quad.score(life_features_train_quad, life_labels_train)
print(accuracy_score_quad)
# Out:
# 0.9999980015924387

# %%
poly_model_quad_predict = poly_model_quad.predict(life_features_test_quad)
print("Mean squared error: %.2f"
      % mean_squared_error(life_labels_test, poly_model_quad_predict))
print("Mean absolute error: %.2f"
      % mean_absolute_error(life_labels_test, poly_model_quad_predict))
print('R_square score: %.2f' % r2_score(life_labels_test, poly_model_quad_predict))
# Out:
# Mean squared error: 3009.26
# Mean absolute error: 31.20
# R_square score: -35.63

# %% [markdown]
# # Random Forest Regression
# The alogorithm has learned 99% on the training data without cross validation and  with 91%  cross validation, the value is 92 % on the test data.
#
#  After performing grid search in the range 2 to 10 for the minimun samples split we get 3 for the split. The R square on the training is 99 % while on the test it is 92% and a MAE of 2.04 and MSE of 6.39.

# %%
import numpy as np
random_forest_model = RandomForestRegressor()
random_forest_fit = random_forest_model.fit(life_features_train, life_labels_train)

random_forest_score = cross_val_score(random_forest_fit, life_features_train, life_labels_train, cv = 5)
print("mean cross validation score: %.2f"
       % np.mean(random_forest_score))
print("score without cv: %.2f"
      % random_forest_fit.score(life_features_train, life_labels_train))
print("R^2 score on the test data %.2f"
      # %r2_score(life_labels_test, random_forest_fit.predict(life_features_test)))
# Out:
# mean cross validation score: 0.91
# score without cv: 0.99
# R^2 score on the test data 0.92

# %%
random_forest_model_predict = random_forest_model.predict(life_features_test)

scoring = make_scorer(r2_score)
grid_cv = GridSearchCV(RandomForestRegressor(),
              param_grid={'min_samples_split': range(2, 10)},
              scoring=scoring, cv=5, refit=True)

grid_cv.fit(life_features_train, life_labels_train)
grid_cv.best_params_

result = grid_cv.cv_results_
print("Best Parameters: " + str(grid_cv.best_params_))
result = grid_cv.cv_results_
print("R^2 score on training data: %.2f"  % grid_cv.best_estimator_.score(life_features_train, life_labels_train))
print("R^2 score: %.2f"
      % r2_score(life_labels_test, grid_cv.best_estimator_.predict(life_features_test)))
print("Mean squared error: %.2f"
      % mean_squared_error(life_labels_test, random_forest_model_predict))
print("Mean absolute error: %.2f"
      % mean_absolute_error(life_labels_test, random_forest_model_predict))
# Out:
# Best Parameters: {'min_samples_split': 3}
# R^2 score on training data: 0.99
# R^2 score: 0.92
# Mean squared error: 6.39
# Mean absolute error: 2.04

# %%
# Conclusion
Random Forest Regression gives the highest accuracy i.e 92% followed by Lasso and Elastic Regression :89%.
Ridge Regression gives accuracy score of 88%.
Polynomial Regression is a bad fit and gives a negative R square value.

# %% [markdown]
# # Deployment
# I used Node-RED and Watson Machine Learning Client for deploying the model.

# %%
# !pip install watson-machine-learning-client

# %%
from watson_machine_learning_client import WatsonMachineLearningAPIClient
# Out:
# 2020-05-31 03:09:25,104 - watson_machine_learning_client.metanames - WARNING - 'AUTHOR_EMAIL' meta prop is deprecated. It will be ignored.

# %%
client = WatsonMachineLearningAPIClient( wml_credentials )

# %%
model_props = {client.repository.ModelMetaNames.AUTHOR_NAME: "Vedita", 
               client.repository.ModelMetaNames.AUTHOR_EMAIL: "kamatvedita99@gmail.com", 
               client.repository.ModelMetaNames.NAME: "LifeExpectancy"}

# %%
model_artifact =client.repository.store_model(grid_cv, meta_props=model_props)

# %%
published_model_uid = client.repository.get_model_uid(model_artifact)

# %% [markdown]
# deployment = client.deployments.create(published_model_uid, name="LifeExpectancy")

# %% [markdown]
# scoring_endpoint = client.deployments.get_scoring_url(deployment)
